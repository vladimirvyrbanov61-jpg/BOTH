# %% [markdown]
# # SIMON 32/64 — Assignment cryptanalysis experiments
#
# Track A: autoencoder scores vs round count. Track B: neural distinguisher (Simon pairs vs random).
#
# Upload or clone the repository, then set `ROOT` to the repo directory.

# %%
# Option A: upload zip and unzip
# Option B: git clone
# !git clone https://YOUR_REPO.git Simon
# %cd Simon

# %%
# !pip install -q -r requirements-colab.txt

# %%
import sys
from pathlib import Path
ROOT = Path('.').resolve()
sys.path.insert(0, str(ROOT))

# %%
# !python ml/train.py --torch-only --n-samples 20000 --epochs 40

# %%
# Full assignment run (use --quick for a faster smoke test)
# !python experiments/run_all.py --config configs/cryptanalysis.yaml

# %%
from IPython.display import Image, Markdown, display
display(Image('results/round_sweep/score_vs_rounds.png'))
display(Image('results/distinguisher/advantage_vs_rounds.png'))

# %%
from pathlib import Path
summary = Path('results/ASSIGNMENT_SUMMARY.md').read_text(encoding='utf-8')
display(Markdown(summary))
